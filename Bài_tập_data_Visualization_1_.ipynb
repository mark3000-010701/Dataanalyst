# %% [markdown]
# <a href="https://colab.research.google.com/github/mark3000-010701/Dataanalyst/blob/main/B%C3%A0i_t%E1%BA%ADp_data_Visualization_1_.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **[Bài tập] Trực quan hóa cơ bản dữ liệu GDP list**

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn

# %%
df=pd.read_csv('https://s3.ap-southeast-1.amazonaws.com/learn.codegym.vn/media/public/2021/12/31020936/GDPlist.csv',encoding='ISO-8859-1')
df.head()
# Out:
#         Country      Continent  GDP (millions of US$)
# 0   Afghanistan           Asia                  18181
# 1       Albania         Europe                  12847
# 2       Algeria         Africa                 190709
# 3        Angola         Africa                 100948
# 4     Argentina  South America                 447644

# %%
df.isnull()
# Out:
#      Country  Continent  GDP (millions of US$)
# 0      False      False                  False
# 1      False      False                  False
# 2      False      False                  False
# 3      False      False                  False
# 4      False      False                  False
# ..       ...        ...                    ...
# 120    False      False                  False
# 121    False      False                  False
# 122    False      False                  False
# 123    False      False                  False
# 124    False      False                  False
#
# [125 rows x 3 columns]

# %% [markdown]
# # So sánh GDP các nước ở South America.

# %%
df1=df[df['Continent']=='South America']
df1
# Out:
#         Country      Continent  GDP (millions of US$)
# 4     Argentina  South America                 447644
# 15       Brazil  South America                2492908
# 22        Chile  South America                 248411
# 24     Colombia  South America                 328422
# 34      Ecuador  South America                  66381
# 86     Paraguay  South America                  21236
# 87         Peru  South America                 173502
# 119     Uruguay  South America                  46872
# 121   Venezuela  South America                 315841

# %%
from matplotlib.pyplot import figure
figure(figsize=(16, 9), dpi=80)
plt.bar(df1['Country'], df1['GDP (millions of US$)'], width = 0.5)
plt.title('GDP in South America', fontsize = 16, color = 'r')
plt.xlabel('Country', fontsize = 14)
plt.ylabel('GDP', fontsize = 14)
plt.show()

# %% [markdown]
# # **Đánh giá tỉ lệ đóng góp GDP của Việt Nam trên tổng số GDP của 5 nước Đông Nam Á là Vietnam,  Indonesia, Cambodia, Thailand và Malaysia.**

# %%
df2=df[df['Continent']=='Asia']
df2
# Out:
#                    Country Continent  GDP (millions of US$)
# 0              Afghanistan      Asia                  18181
# 8                  Bahrain      Asia                  26108
# 9               Bangladesh      Asia                 113032
# 16                  Brunei      Asia                  15533
# 18                   Burma      Asia                  51925
# 19                Cambodia      Asia                  12861
# 23                   China      Asia                7298147
# 49               Hong Kong      Asia                 243302
# 52                   India      Asia                1676143
# 53               Indonesia      Asia                 845680
# 54                    Iran      Asia                 482445
# 55                    Iraq      Asia                 115388
# 57                  Israel      Asia                 242897
# 60                   Japan      Asia                5869471
# 62              Kazakhstan      Asia                 178312
# 64                  Kuwait      Asia                 176667
# 66                 Lebanon      Asia                  39039
# 70                Malaysia      Asia                 278680
# 77                   Nepal      Asia                  18580
# 82                    Oman      Asia                  71888
# 83                Pakistan      Asia                 210566
# 88             Philippines      Asia                 213129
# 91                   Qatar      Asia                 173847
# 93                  Russia      Asia                1850401
# 94            Saudi Arabia      Asia                 577595
# 97               Singapore      Asia                 259849
# 101            South Korea      Asia                1116247
# 103              Sri Lanka      Asia                  59095
# 107                 Taiwan      Asia                 466832
# 109               Thailand      Asia                 345649
# 111                Tunisia      Asia                  46360
# 112                 Turkey      Asia                 778089
# 113           Turkmenistan      Asia                  25742
# 116   United Arab Emirates      Asia                 360136
# 120             Uzbekistan      Asia                  45353
# 122                Vietnam      Asia                 122722

# %%
df2['Country']=df2['Country'].str.strip()
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.

# %%
df3=df2[(df2['Country']=='Vietnam')]
df4=df2[(df2['Country']=='Cambodia')]
df5=df2[(df2['Country']=='Malaysia')]
df6=df2[(df2['Country']=='Indonesia')]
df7=df2[(df2['Country']=='Thailand')]

# %%
df9=df2[(df2['Country']=='Vietnam') | (df2['Country']=='Indonesia') | (df2['Country']=='Cambodia') | (df2['Country']=='Thailand') | (df2['Country']=='Malaysia')]
df9
# Out:
#        Country Continent  GDP (millions of US$)
# 19    Cambodia      Asia                  12861
# 53   Indonesia      Asia                 845680
# 70    Malaysia      Asia                 278680
# 109   Thailand      Asia                 345649
# 122    Vietnam      Asia                 122722

# %%
df4
# Out:
#      Country Continent  GDP (millions of US$)
# 19  Cambodia      Asia                  12861

# %%
from matplotlib.pyplot import figure
figure(figsize=(16, 9), dpi=80)
myexplode = [0, 0, 0, 0,0.2]
plt.pie(df9['GDP (millions of US$)'],labels=df9['Country'],explode=myexplode)
plt.legend(title='GDP of VietNam in South East Asia')
plt.show()

# %% [markdown]
# # **[Bài tập] Phân tích bộ dữ liệu HousePrice _ Đống Đa**

# %%
data=pd.read_excel('https://s3.ap-southeast-1.amazonaws.com/learn.codegym.vn/media/public/2022/01/08185826/house_price_do%CC%82%CC%81ng-da.xlsx')
data.head()
# Out:
# /usr/local/lib/python3.7/dist-packages/openpyxl/worksheet/_reader.py:312: UserWarning: Unknown extension is not supported and will be removed
#   warn(msg)
#                                                title  \
# 0  Bán nhà Trần Quang Diệu mới coong đẹp 50m2x6 t...
# 1  Bán nhà mặt phố Tây Sơn - 6 tầng. Kinh doanh t...
# 2  Bán nhà số 36 Đoàn Kết - phố Khâm Thiên - Đống...
# 3  Bán nhà 6 tầng mới kinh doanh mặt ngõ 1194 Đườ...
# 4  Bán nhà mặt phố Thái Hà 70m2, 5 tầng, 4.5m mặt...
#
#                                              address  area    price  \
# 0  Đường Trần Quang Diệu, Phường Trung Liệt, Đốn...  50.0  14700.0
# 1  Đường Tây Sơn, Phường Trung Liệt, Đống Đa, Hà...  35.0  12500.0
# 2  Số 36 Đoàn Kết, Phố Khâm Thiên, Phường Thổ Qu...  57.0   4200.0
# 3  Ngõ 1194, Đường Láng, Phường Láng Thượng, Đố...  62.0  11000.0
# 4   Phố Thái Hà, Phường Trung Liệt, Đống Đa, Hà Nội  70.0  36000.0
#
#     postDate land_certificate house_direction balcony_direction  toilet  \
# 0 2021-01-01            Sổ đỏ             NaN               NaN     4.0
# 1 2021-02-19            Sổ đỏ             NaN               NaN     NaN
# 2 2021-03-10            Sổ đỏ             Nam               Nam     3.0
# 3 2021-03-13            Sổ đỏ            Đông          Đông-Nam     6.0
# 4 2021-03-13            Sổ đỏ             NaN               NaN     NaN
#
#    bedroom  floor        type_of_land            street_name  \
# 0      6.0    6.0    Bán nhà riêng\n   Đường Trần Quang Diệu
# 1      NaN    6.0  Bán nhà mặt phố\n          Phố Trung Liệt
# 2      8.0    4.0    Bán nhà riêng\n          Phố Khâm Thiên
# 3      5.0    6.0    Bán nhà riêng\n       Đường Láng Thượng
# 4      6.0    5.0  Bán nhà mặt phố\n          Phố Trung Liệt
#
#             ward_name district_name         city_name        lat        long
# 0   Phường Trung Liệt  Quận Đống Đa  Thành phố Hà Nội  21.015698  105.824583
# 1   Phường Trung Liệt  Quận Đống Đa  Thành phố Hà Nội  21.008930  105.824105
# 2   Phường Khâm Thiên  Quận Đống Đa  Thành phố Hà Nội  21.025208  105.833111
# 3  Phường Láng Thượng  Quận Đống Đa  Thành phố Hà Nội  21.025379  105.801011
# 4   Phường Trung Liệt  Quận Đống Đa  Thành phố Hà Nội  21.009239  105.824230

# %% [markdown]
# # Vẽ biểu đồ phân tích mối liên hệ giữa diện tích với giá nhà, giữa số phòng ngủ với giá nhà, giữa số toilet với giá nhà.

# %%
data1=data[['area','bedroom','toilet','price']]
data1
# Out:
#       area  bedroom  toilet    price
# 0     50.0      6.0     4.0  14700.0
# 1     35.0      NaN     NaN  12500.0
# 2     57.0      8.0     3.0   4200.0
# 3     62.0      5.0     6.0  11000.0
# 4     70.0      6.0     NaN  36000.0
# ..     ...      ...     ...      ...
# 995   65.0      6.0     NaN  17500.0
# 996   60.0      NaN     NaN  17500.0
# 997   45.0      NaN     NaN  24800.0
# 998  178.0      3.0     4.0   8100.0
# 999  107.0      NaN     NaN  45000.0
#
# [1000 rows x 4 columns]

# %%
data2=data1[data1.bedroom.isna()==False]
data2
# Out:
#       area  bedroom  toilet    price
# 0     50.0      6.0     4.0  14700.0
# 2     57.0      8.0     3.0   4200.0
# 3     62.0      5.0     6.0  11000.0
# 4     70.0      6.0     NaN  36000.0
# 5     41.0      3.0     5.0  13500.0
# ..     ...      ...     ...      ...
# 992   56.0      6.0     6.0      NaN
# 993  168.0      3.0     3.0  23500.0
# 994   25.0      2.0     3.0   2850.0
# 995   65.0      6.0     NaN  17500.0
# 998  178.0      3.0     4.0   8100.0
#
# [635 rows x 4 columns]

# %%
data3=data2[data2.toilet.isna()==False]

# %%
data4=data3[data3.price.isna()==False]
data4
# Out:
#       area  bedroom  toilet    price
# 0     50.0      6.0     4.0  14700.0
# 2     57.0      8.0     3.0   4200.0
# 3     62.0      5.0     6.0  11000.0
# 5     41.0      3.0     5.0  13500.0
# 6     50.0      4.0     5.0  13000.0
# ..     ...      ...     ...      ...
# 990  168.0      4.0     5.0   3700.0
# 991  180.0      4.0     5.0   4100.0
# 993  168.0      3.0     3.0  23500.0
# 994   25.0      2.0     3.0   2850.0
# 998  178.0      3.0     4.0   8100.0
#
# [545 rows x 4 columns]

# %%
from matplotlib.pyplot import figure
figure(figsize=(8, 6), dpi=80)
plt.hist(data4['price'])
plt.show()

# %% [markdown]
# # Vẽ biểu đồ thể hiện tỉ lệ % bài đăng (bản ghi) giữa các hình thức nhà (type_of_land).

# %%
data_type_of_land = data['type_of_land'].value_counts()
data_type_of_land
# Out:
# Bán nhà riêng           348
# Bán nhà riêng\n         254
# Bán nhà mặt phố\n       176
# Tập thể, cư xá           69
# Bán nhà mặt phố          65
# Chung cư                 59
# Bất động sản khác        11
# Bất động sản khác\n      10
# Đất thổ cư                8
# Name: type_of_land, dtype: int64

# %%
ck=pd.DataFrame(data_type_of_land)

# %%
from matplotlib.pyplot import figure
figure(figsize=(16, 9), dpi=80)
myexplode = [0.2, 0, 0, 0, 0, 0, 0, 0, 0]
plt.pie(ck)
plt.legend(title='Tỉ lệ bản ghi giữa các hình thức bán nhà( Type_of_land) :')
plt.show()
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:4: MatplotlibDeprecationWarning: Non-1D inputs to pie() are currently squeeze()d, but this behavior is deprecated since 3.1 and will be removed in 3.3; pass a 1D array instead.
#   after removing the cwd from sys.path.
# No handles with labels found to put in legend.

# %% [markdown]
# # Vẽ biểu đồ so sánh giá nhà trung bình trên 1 m2 giữa các hình thức nhà (type_of_land)

# %%
dt = data[['type_of_land','price']]
dt
# Out:
#            type_of_land    price
# 0      Bán nhà riêng\n   14700.0
# 1    Bán nhà mặt phố\n   12500.0
# 2      Bán nhà riêng\n    4200.0
# 3      Bán nhà riêng\n   11000.0
# 4    Bán nhà mặt phố\n   36000.0
# ..                  ...      ...
# 995  Bán nhà mặt phố\n   17500.0
# 996  Bán nhà mặt phố\n   17500.0
# 997  Bán nhà mặt phố\n   24800.0
# 998       Bán nhà riêng   8100.0
# 999  Bán nhà mặt phố\n   45000.0
#
# [1000 rows x 2 columns]

# %%
dt=dt[dt.price.isna()==False]
dt
# Out:
#            type_of_land    price
# 0      Bán nhà riêng\n   14700.0
# 1    Bán nhà mặt phố\n   12500.0
# 2      Bán nhà riêng\n    4200.0
# 3      Bán nhà riêng\n   11000.0
# 4    Bán nhà mặt phố\n   36000.0
# ..                  ...      ...
# 995  Bán nhà mặt phố\n   17500.0
# 996  Bán nhà mặt phố\n   17500.0
# 997  Bán nhà mặt phố\n   24800.0
# 998       Bán nhà riêng   8100.0
# 999  Bán nhà mặt phố\n   45000.0
#
# [944 rows x 2 columns]

# %%
dt=dt[dt.type_of_land.isna()==False]
dt
# Out:
#            type_of_land    price
# 0      Bán nhà riêng\n   14700.0
# 1    Bán nhà mặt phố\n   12500.0
# 2      Bán nhà riêng\n    4200.0
# 3      Bán nhà riêng\n   11000.0
# 4    Bán nhà mặt phố\n   36000.0
# ..                  ...      ...
# 995  Bán nhà mặt phố\n   17500.0
# 996  Bán nhà mặt phố\n   17500.0
# 997  Bán nhà mặt phố\n   24800.0
# 998       Bán nhà riêng   8100.0
# 999  Bán nhà mặt phố\n   45000.0
#
# [944 rows x 2 columns]

# %%
dt1 = dt.groupby(['type_of_land'])['price'].mean().reset_index(name='mean_price')
dt1
# Out:
#            type_of_land    mean_price
# 0       Bán nhà mặt phố  38816.227869
# 1    Bán nhà mặt phố\n   77905.654762
# 2         Bán nhà riêng   6052.253968
# 3      Bán nhà riêng\n   10959.577959
# 4     Bất động sản khác  18492.222222
# 5  Bất động sản khác\n   23437.000000
# 6              Chung cư   2011.864407
# 7        Tập thể, cư xá   2094.637681
# 8            Đất thổ cư  10585.000000

# %%
plt.pie(dt1['mean_price'],labels=dt1['type_of_land'])
# Out:
# ([<matplotlib.patches.Wedge at 0x7f77d1fe6550>,
#   <matplotlib.patches.Wedge at 0x7f77d1fe6890>,
#   <matplotlib.patches.Wedge at 0x7f77d1fe6950>,
#   <matplotlib.patches.Wedge at 0x7f77d1fb8050>,
#   <matplotlib.patches.Wedge at 0x7f77d1fb8e90>,
#   <matplotlib.patches.Wedge at 0x7f77d1fb6510>,
#   <matplotlib.patches.Wedge at 0x7f77d1fb6250>,
#   <matplotlib.patches.Wedge at 0x7f77d1fb68d0>,
#   <matplotlib.patches.Wedge at 0x7f77d1fb8610>],
#  [Text(0.8818981719510851, 0.65746149264374, 'Bán nhà mặt phố'),
#   Text(-0.9233474150368571, 0.5978541219601602, 'Bán nhà mặt phố\n '),
#   Text(-0.7576286397360217, -0.7974953568841299, 'Bán nhà riêng'),
#   Text(-0.506987292838098, -0.9761986913024914, 'Bán nhà riêng\n '),
#   Text(0.007769895901217678, -1.099972558165741, 'Bất động sản khác'),
#   Text(0.7078480922674012, -0.8419923267307138, 'Bất động sản khác\n '),
#   Text(0.9896622190211783, -0.4801756889327878, 'Chung cư'),
#   Text(1.019908422222764, -0.41205195094681024, 'Tập thể, cư xá'),
#   Text(1.0832577805137416, -0.19118729287388023, 'Đất thổ cư')])

# %% [markdown]
# # Vẽ biểu đồ thể hiện sự thay đổi giá nhà trung bình trên 1m2 theo số lượng phòng ngủ.

# %%
test=data[['bedroom','price']]
test
# Out:
#      bedroom    price
# 0        6.0  14700.0
# 1        NaN  12500.0
# 2        8.0   4200.0
# 3        5.0  11000.0
# 4        6.0  36000.0
# ..       ...      ...
# 995      6.0  17500.0
# 996      NaN  17500.0
# 997      NaN  24800.0
# 998      3.0   8100.0
# 999      NaN  45000.0
#
# [1000 rows x 2 columns]

# %%
test1=test[test.bedroom.isna()==False]

# %%
test1=test1[test1.price.isna()==False]

# %%
check= test1.groupby(['bedroom'])['price'].mean().reset_index(name='mean_for_bedroom')
check
# Out:
#     bedroom  mean_for_bedroom
# 0       1.0      12149.148936
# 1       2.0       4026.666000
# 2       3.0       9142.038217
# 3       4.0       9666.037736
# 4       5.0      20816.666667
# 5       6.0      19570.967742
# 6       7.0      18861.250000
# 7       8.0      22700.000000
# 8       9.0      18200.000000
# 9      10.0     320686.363636
# 10     11.0      10550.000000
# 11     12.0     106775.000000
# 12     13.0       7800.000000
# 13     14.0      30250.000000
# 14     17.0      20000.000000
# 15     22.0      41000.000000

# %%
plt.bar(check['bedroom'],check['mean_for_bedroom'])
# Out:
# <BarContainer object of 16 artists>

# %% [markdown]
# # **[Bài tập] Phân tích bộ dữ liệu Shopee.ph**

# %%
dataframe = pd.read_csv('https://s3.ap-southeast-1.amazonaws.com/learn.codegym.vn/media/public/2022/01/20125029/shopeep_koreantop_clothing_shop_data.csv')
dataframe.head()
# Out:
#              pk_shop date_collected     shopid                  name  \
# 0  20210613254711738     2021-06-13  254711738          hello.may.ph
# 1  20210613314198143     2021-06-13  314198143       love.women.shop
# 2   2021061310377223     2021-06-13   10377223         R&O RedOrange
# 3   2021061321407329     2021-06-13   21407329           patriciacai
# 4   2021061311187885     2021-06-13   11187885  Little Market Manila
#
#   join_month  join_day  join_year  item_count  follower_count response_time  \
# 0      April        27       2020         446           17487      10:13:55
# 1  September        25       2020         263            8574      10:43:05
# 2  September        27       2016         209          660417      08:32:07
# 3      April        30       2017         165           18787      09:10:38
# 4    October        18       2016         467           67371      11:40:59
#
#    response_rate               shop_location  rating_bad  rating_good  \
# 0             96                         NaN         181        17510
# 1             73    San Nicolas,Metro Manila          78         2656
# 2             90     Pasay City,Metro Manila        4647      1071829
# 3             94        Binondo,Metro Manila          44        18959
# 4             89  Caloocan City,Metro Manila         680        39252
#
#    rating_normal  rating_star  is_shopee_verified  is_official_shop
# 0            729         4.81                   1                 0
# 1            198         4.68                   0                 0
# 2          18073         4.91                   1                 0
# 3            215         4.94                   1                 0
# 4           2383         4.73                   1                 0

# %%
dataframe.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 746 entries, 0 to 745
# Data columns (total 18 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   pk_shop             746 non-null    int64
#  1   date_collected      746 non-null    object
#  2   shopid              746 non-null    int64
#  3   name                746 non-null    object
#  4   join_month          746 non-null    object
#  5   join_day            746 non-null    int64
#  6   join_year           746 non-null    int64
#  7   item_count          746 non-null    int64
#  8   follower_count      746 non-null    int64
#  9   response_time       746 non-null    object
#  10  response_rate       746 non-null    int64
#  11  shop_location       428 non-null    object
#  12  rating_bad          746 non-null    int64
#  13  rating_good         746 non-null    int64
#  14  rating_normal       746 non-null    int64
#  15  rating_star         740 non-null    float64
#  16  is_shopee_verified  746 non-null    int64
#  17  is_official_shop    746 non-null    int64
# dtypes: float64(1), int64(12), object(5)
# memory usage: 105.0+ KB

# %% [markdown]
# # Vẽ biểu đồ so sánh số lượng shop gia nhập theo các năm.

# %%
dk=dataframe[['name','join_year']]
dk
# Out:
#                      name  join_year
# 0            hello.may.ph       2020
# 1         love.women.shop       2020
# 2           R&O RedOrange       2016
# 3             patriciacai       2017
# 4    Little Market Manila       2016
# ..                    ...        ...
# 741     Yacent_thrift_Clo       2021
# 742           Akistore.ph       2021
# 743          Yzanice Shop       2020
# 744        Clairecvc Shop       2017
# 745           angelcity.💋       2017
#
# [746 rows x 2 columns]

# %%
dk=dk.groupby('join_year')['name'].count().reset_index(name='amount join')
dk
# Out:
#    join_year  amount join
# 0       2015            4
# 1       2016           27
# 2       2017          156
# 3       2018           87
# 4       2019          106
# 5       2020          247
# 6       2021          119

# %%
plt.bar(dk['join_year'],dk['amount join'])
plt.legend(title='số lượng shop gia nhập theo các năm')
plt.show()
# Out:
# No handles with labels found to put in legend.

# %% [markdown]
# # Vẽ biểu đồ thể hiện mối quan hệ giữa tỉ lệ phản hồi với số lượt khách hàng đánh giá tốt.

# %%
dk1=dataframe[['response_rate','rating_good']]
dk1
# Out:
#      response_rate  rating_good
# 0               96        17510
# 1               73         2656
# 2               90      1071829
# 3               94        18959
# 4               89        39252
# ..             ...          ...
# 741             86           32
# 742             91            9
# 743             96          463
# 744             73       103289
# 745             36       708666
#
# [746 rows x 2 columns]

# %%
dk1=dk1[dk1.rating_good.isna()==False]
dk1
# Out:
#      response_rate  rating_good
# 0               96        17510
# 1               73         2656
# 2               90      1071829
# 3               94        18959
# 4               89        39252
# ..             ...          ...
# 741             86           32
# 742             91            9
# 743             96          463
# 744             73       103289
# 745             36       708666
#
# [746 rows x 2 columns]

# %%
plt.scatter(dk1['response_rate'],dk1['rating_good'])

# %% [markdown]
# # Vẽ biểu đồ thể hiện mối quan hệ giữa thời gian phản hồi (đơn vị giây) với số lượt khách hàng đánh giá xấu.

# %%
dk2=dataframe[['response_time','rating_bad']]
dk2
# Out:
#     response_time  rating_bad
# 0        10:13:55         181
# 1        10:43:05          78
# 2        08:32:07        4647
# 3        09:10:38          44
# 4        11:40:59         680
# ..            ...         ...
# 741      08:45:30           0
# 742      08:01:23           1
# 743      08:46:30          16
# 744      12:19:44        1960
# 745      10:02:42       13401
#
# [746 rows x 2 columns]

# %%
from datetime import datetime
pt = datetime.strptime(dk2['response_time'].loc[1],'%H:%M:%S')
total_seconds = pt.second + pt.minute*60 + pt.hour*3600

# %% [markdown]
# # Vẽ biểu đồ thể hiện xu hướng của số lượng shop gia nhập theo thời gian.

# %%
d=dataframe[['name','join_year','join_month','join_day']]
d
# Out:
#                      name  join_year join_month  join_day
# 0            hello.may.ph       2020      April        27
# 1         love.women.shop       2020  September        25
# 2           R&O RedOrange       2016  September        27
# 3             patriciacai       2017      April        30
# 4    Little Market Manila       2016    October        18
# ..                    ...        ...        ...       ...
# 741     Yacent_thrift_Clo       2021        May        22
# 742           Akistore.ph       2021      March         3
# 743          Yzanice Shop       2020   December        20
# 744        Clairecvc Shop       2017     August         2
# 745           angelcity.💋       2017       June        17
#
# [746 rows x 4 columns]

# %%
d1=d.groupby('join_year')['name'].count().reset_index(name='amount join')
d1
# Out:
#    join_year  amount join
# 0       2015            4
# 1       2016           27
# 2       2017          156
# 3       2018           87
# 4       2019          106
# 5       2020          247
# 6       2021          119

# %%
d2=d.groupby('join_month')['name'].count().reset_index(name='amount join')
#d1=d1.sort_index('join_month')
d2
# Out:
#    join_month  amount join
# 0       April           74
# 1      August           57
# 2    December           55
# 3    February           30
# 4     January           49
# 5        July           46
# 6        June           50
# 7       March           75
# 8         May           75
# 9    November           54
# 10    October           94
# 11  September           87

# %%
d3=d.groupby('join_day')['name'].count().reset_index(name='amount join')
#d1=d1.sort_index('join_month')
d3
# Out:
#     join_day  amount join
# 0          1           24
# 1          2           18
# 2          3           44
# 3          4           12
# 4          5           18
# 5          6           16
# 6          7           20
# 7          8           18
# 8          9           20
# 9         10           17
# 10        11           34
# 11        12           22
# 12        13           14
# 13        14           20
# 14        15           28
# 15        16           30
# 16        17           25
# 17        18           19
# 18        19           37
# 19        20           24
# 20        21           23
# 21        22           30
# 22        23           28
# 23        24           19
# 24        25           12
# 25        26           33
# 26        27           36
# 27        28           48
# 28        29           20
# 29        30           23
# 30        31           14

# %%
from matplotlib.pyplot import figure
figure(figsize=(16, 9), dpi=80)
plt.subplot(1,3,1)
plt.bar(d1['join_year'],d1['amount join'])

plt.subplot(1,3,2)
plt.xticks(rotation=45)
plt.bar(d2['join_month'],d2['amount join'])

plt.subplot(1,3,3)
plt.plot(d3['join_day'],d3['amount join'])


plt.show()

# %% [markdown]
# # Vẽ biểu đồ thể hiện phân bố của điểm đánh giá trung bình.

# %%
k=dataframe[['rating_star']]

# %%
plt.hist(k)
plt.show()
# Out:
# /usr/local/lib/python3.7/dist-packages/matplotlib/axes/_axes.py:6630: RuntimeWarning: All-NaN slice encountered
#   xmin = min(xmin, np.nanmin(xi))
# /usr/local/lib/python3.7/dist-packages/matplotlib/axes/_axes.py:6631: RuntimeWarning: All-NaN slice encountered
#   xmax = max(xmax, np.nanmax(xi))

# %%
import seaborn as sns
sns.kdeplot(data=k)
