# %% [markdown]
# <a href="https://colab.research.google.com/github/mark3000-010701/Dataanalyst/blob/main/Th%E1%BB%B1c_H%C3%A0nh_Pandas_1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # [Thực hành] Đọc dữ liệu vào DataFrame

# %% [markdown]
# ## 1. Đọc dữ liệu từ file csv

# %%
import pandas as pd

# %%
df = pd.read_csv('https://s3.ap-southeast-1.amazonaws.com/learn.codegym.vn/media/public/2021/12/31021019/FoodPrice_in_Turkey.csv')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7381 entries, 0 to 7380
# Data columns (total 8 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   Place        7381 non-null   object
#  1   ProductId    7381 non-null   int64
#  2   ProductName  7381 non-null   object
#  3   UmId         7381 non-null   int64
#  4   UmName       7381 non-null   object
#  5   Month        7381 non-null   int64
#  6   Year         7381 non-null   int64
#  7   Price        7381 non-null   float64
# dtypes: float64(1), int64(4), object(3)
# memory usage: 461.4+ KB

# %%
df.head()
# Out:
#               Place  ProductId    ProductName  UmId UmName  Month  Year  \
# 0  National Average         52  Rice - Retail     5     KG      5  2013
# 1  National Average         52  Rice - Retail     5     KG      6  2013
# 2  National Average         52  Rice - Retail     5     KG     11  2013
# 3  National Average         52  Rice - Retail     5     KG     12  2013
# 4  National Average         52  Rice - Retail     5     KG      1  2014
#
#     Price
# 0  4.4920
# 1  4.5786
# 2  4.7865
# 3  5.1337
# 4  5.5099

# %% [markdown]
# ## 2. Đọc dữ liệu từ file excel

# %%
df1 = pd.read_excel('https://s3.ap-southeast-1.amazonaws.com/learn.codegym.vn/media/public/2022/01/08185826/house_price_do%CC%82%CC%81ng-da.xlsx')
# Out:
# /usr/local/lib/python3.7/dist-packages/openpyxl/worksheet/_reader.py:312: UserWarning: Unknown extension is not supported and will be removed
#   warn(msg)

# %%
df1.head()
# Out:
#                                                title  \
# 0  Bán nhà Trần Quang Diệu mới coong đẹp 50m2x6 t...
# 1  Bán nhà mặt phố Tây Sơn - 6 tầng. Kinh doanh t...
# 2  Bán nhà số 36 Đoàn Kết - phố Khâm Thiên - Đống...
# 3  Bán nhà 6 tầng mới kinh doanh mặt ngõ 1194 Đườ...
# 4  Bán nhà mặt phố Thái Hà 70m2, 5 tầng, 4.5m mặt...
#
#                                              address  area    price  \
# 0  Đường Trần Quang Diệu, Phường Trung Liệt, Đốn...  50.0  14700.0
# 1  Đường Tây Sơn, Phường Trung Liệt, Đống Đa, Hà...  35.0  12500.0
# 2  Số 36 Đoàn Kết, Phố Khâm Thiên, Phường Thổ Qu...  57.0   4200.0
# 3  Ngõ 1194, Đường Láng, Phường Láng Thượng, Đố...  62.0  11000.0
# 4   Phố Thái Hà, Phường Trung Liệt, Đống Đa, Hà Nội  70.0  36000.0
#
#     postDate land_certificate house_direction balcony_direction  toilet  \
# 0 2021-01-01            Sổ đỏ             NaN               NaN     4.0
# 1 2021-02-19            Sổ đỏ             NaN               NaN     NaN
# ...

# %% [markdown]
# ## 3. Đọc dữ liệu từ file Json

# %%
df3=pd.read_json('https://raw.githubusercontent.com/hainmit09/DataAnalysis/main/Bai_2_data/FoodPrice_in_Turkey.json')
df3.head()
# Out:
#               Place  ProductId    ProductName  UmId UmName  Month  Year  \
# 0  National Average         52  Rice - Retail     5     KG      5  2013
# 1  National Average         52  Rice - Retail     5     KG      6  2013
# 2  National Average         52  Rice - Retail     5     KG     11  2013
# 3  National Average         52  Rice - Retail     5     KG     12  2013
# 4  National Average         52  Rice - Retail     5     KG      1  2014
#
#     Price
# 0  4.4920
# 1  4.5786
# 2  4.7865
# 3  5.1337
# 4  5.5099

# %% [markdown]
# ## 4. Đọc dữ liệu từ file hdf5

# %%
df4 = pd.read_hdf('/content/sample_data/FoodPrice_in_Turkey (1).hdf')
df4.head()
# Out:
#               Place  ProductId    ProductName  UmId UmName  Month  Year  \
# 0  National Average         52  Rice - Retail     5     KG      5  2013
# 1  National Average         52  Rice - Retail     5     KG      6  2013
# 2  National Average         52  Rice - Retail     5     KG     11  2013
# 3  National Average         52  Rice - Retail     5     KG     12  2013
# 4  National Average         52  Rice - Retail     5     KG      1  2014
#
#     Price
# 0  4.4920
# 1  4.5786
# 2  4.7865
# 3  5.1337
# 4  5.5099

# %% [markdown]
# ## 5. Đọc dữ liệu từ file html

# %%
df5 = pd.read_html('https://en.wikipedia.org/wiki/List_of_sovereign_states_and_dependent_territories_in_North_America')
df5[0].head()
# Out:
#    Flag        English short name            English long name  \
# 0   NaN  Antigua and Barbuda[n 1]          Antigua and Barbuda
# 1   NaN         Bahamas, The[n 1]  Commonwealth of The Bahamas
# 2   NaN             Barbados[n 1]                     Barbados
# 3   NaN          Belize[n 1][n 2]                       Belize
# 4   NaN               Canada[n 3]                       Canada
#
#           Domestic short name(s)     Capital               Currency  \
# 0   English: Antigua and Barbuda  St. John's  East Caribbean dollar
# 1               English: Bahamas      Nassau        Bahamian dollar
# 2              English: Barbados  Bridgetown       Barbadian dollar
# 3                English: Belize    Belmopan          Belize dollar
# 4  English: CanadaFrench: Canada      Ottawa        Canadian dollar
#
#    Population
# 0       97118
# 1      389482
# 2      287025
# 3      390353
# 4    35151728

# %%
df5[1].head()
# Out:
#    Flag      English short name       English long name  \
# 0   NaN                Anguilla                Anguilla
# 1   NaN                 Bermuda         Bermuda Islands
# 2   NaN  British Virgin Islands  British Virgin Islands
# 3   NaN          Cayman Islands          Cayman Islands
# 4   NaN         Montserrat[n 1]              Montserrat
#
#                  Domestic short name(s)  \
# 0                     English: Anguilla
# 1  English: BermudaPortuguese: Bermudas
# 2               English: Virgin Islands
# 3               English: Cayman Islands
# 4                   English: Montserrat
#
#                                              Capital               Currency  \
# 0                                         The Valley  East Caribbean dollar
# 1                                           Hamilton       Bermudian dollar
# 2                                          Road Town   United States dollar
# ...
